# %% [markdown]
# # <a id="#">Task 3 – Mean, median, and Gaussian filtering</a>

# %%
import numpy
import matplotlib.pyplot as plt

# %% [markdown]
# ---
#
# ## Linear filtering by convolution (mean filter)
#
# **<a id="#">Task 3.1.1.</a>** Load the image `data/lena.png` and show it:

# %%
img = plt.imread('data/lena.png')
plt.figure(figsize=(5,5))
plt.imshow(img, 'gray')

# %% [markdown]
# **<a id="#">Task 3.1.2.</a>** Implement a mean filter:

# %%
def meanfilter(img, size):
    result = numpy.zeros(img.shape)
    n = (size - 1) // 2
    for p in numpy.ndindex(img.shape):
        neighborhood_sum = 0 
        for q in numpy.ndindex(size,size):
            if p[0]<n or p[0]>img.shape[0]-n-1 or p[1]> img.shape[1]-n-1
                result [p] = 0
            else:
                intensity= img[p[0] + q[0] - n, p[1] + q[1] - n]
                neighborhood_sum += intensity 
        
        result[p[0], p[1]] = neighborhood_sum /size ** 2
    return result

# %% [markdown]
# **<a id="#">Task 3.1.3.</a>** Test your implementation from above by using the function `meanfilter` for the previously loaded image and show the result:

# %%
img_m = meanfilter(img, size = 5)

plt.figure(figsize=(5,5))
plt.imshow(img_m, 'gray')

# %% [markdown]
# **<a id="#">Task 3.1.4.</a>** Compare your result for filter size `5` with the correct result image `data/lena_meanfilter5.png`:

# %%
correct_image = plt.imread('data/lena_meanfilter5.png')

numpy.allclose(img_m, correct_image, atol=1/255)
# Out:
# True

# %% [markdown]
# ---
#
# ## Non-linear filtering
#
# **<a id="#">Task 3.2.1.</a>** Implement a median filter:

# %%
def medianfilter(img, size):
    result = numpy.zeros(img.shape)
    n = (size - 1) // 2
    for p in numpy.ndindex(img.shape):
        neighborhood_sum = 0 
        l = list()
        for q in numpy.ndindex(size,size):
            if p[0]<n or p[0]>img.shape[0]-n-1 or p[1]> img.shape[1]-n-1
                result [p] = 0
            else:
                intensity= img[p[0] + q[0] - n, p[1] + q[1] - n]
                l.append(intesnsity)
                
                neighborhood_sum += intensity 
        
        result[p[0], p[1]] = neighborhood_sum /size ** 2
    return result

# %% [markdown]
# **<a id="#">Task 3.2.2.</a>** First, test your implementation from above by using the function `medianfilter` for the previously loaded image and show the result:

# %%
img_m_2 = medianfilter(img, size = 5)

plt.figure(figsize=(5,5))
plt.imshow(img_m_2, 'gray')

# %% [markdown]
# Then, compare your result for filter size `5` with the correct result image `data/lena_medianfilter5.png`:

# %%
correct_image_2 = plt.imread('data/lena_medianfilter5.png')

numpy.allclose(img_m_2, correct_image_2, atol=1/255)

# %% [markdown]
# ---
#
# ## Using pre-implemented filters
#
# **<a id="#">Task 3.3.1.</a>** Load the package `scipy.ndimage`:

# %%
import scipy.ndimage

# %% [markdown]
# **<a id="#">Task 3.3.2 (a).</a>** Apply a **mean filter** from `scipy.ndimage` to the loaded image:

# %%
timg_a = scipy.ndimage.uniform_filter(img,5)
plt.imshow(timg_a)

# %% [markdown]
# **<a id="#">Task 3.3.2 (b).</a>** Apply a **median filter** from `scipy.ndimage` to the loaded image:

# %% [markdown]
# **<a id="#">Task 3.3.2 (c).</a>** Apply a **Gaussian filter** from `scipy.ndimage` to the loaded image:

# %% [markdown]
# **<a id="#">Task 3.3.3.</a>** Compare the results obtained using the functions from `scipy.ndimage` with those you obtained using your own implementations. What are the main differences? Do you have an explanation?

# %% [markdown]
# ---
#
# ## Slicing and benchmarking
#
# **<a id="#">Task 3.4.2.</a>** Implement either a mean filter or a median filter using only a single `for`-loop:

# %%
def fastfilter(img, size):
    # write your code here

# %% [markdown]
# **<a id="#">Task 3.4.3.</a>** First, test your implementation from above by using the function `fastfilter` for the previously loaded image and show the result:

# %% [markdown]
# Then, compare your result to those obtained using your implementation for either `meanfilter` or `medianfilter`, respectively:

# %% [markdown]
# **<a id="#">Task 3.4.4.</a>** Benchmark the code run times:

# %% [markdown]
# **<a id="#">Task 3.4.5.</a>** Document your observations regarding the benchmarking results and try to think of an explanation:
