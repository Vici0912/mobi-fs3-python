# %% [markdown]
# # <a id="#">Task 4 – Edge detection: Derivative operators</a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import skimage.io

# %% [markdown]
# ---
#
# ## Prewitt filters
#
# **<a id="#">Task 4.1.1.</a>** Load the image `data/lena.png` and show it:

# %%
img = plt.imread('data/lena.png')
plt.figure()
plt.imshow(img)

img_v = img.copy(img)
img_h = img.copy(img)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 5
#       2 plt.figure()
#       3 plt.imshow(img)
# ----> 5 img_v = img.copy(img)
#       6 img_h = img.copy(img)
#
# TypeError: order must be str, not numpy.ndarray

# %% [markdown]
# **<a id="#">Task 4.1.2.</a>** Implement horizontal and vertical $3 \times 3$ Prewitt filters:

# %%
def prewitt_h(img, size):
    result = np.zeros(img.shape)
    n = (size - 1) // 2
    x = np.array([[-1,0, 1], [1, 0, -1], [1, 0, -1]], np.int32)
    for p in np.ndindex(img.shape[1]-2*n, img.shape[0]-2*n):
        neighborhood_sum = 0 
        for q in np.ndindex(size,size):
            pos = tuple(map(lambda x, y: x + y, p, q))
            neighborhood_sum = neighborhood_sum + img[pos] * x[q] 
        result[p[0]+n, p[1]+n] = neighborhood_sum /(size * 2)
    return result
    
def prewitt_v(img, size):
    result = np.zeros(img.shape)
    n = (size - 1) // 2
    x = np.array([[-1,-1, -1], [0, 0, 0], [1, 1, 1]], np.int32)
    for p in np.ndindex(img.shape[1]-2*n, img.shape[0]-2*n):
        neighborhood_sum = 0 
        for q in np.ndindex(size,size):
            pos = tuple(map(lambda x, y: x + y, p, q))
            neighborhood_sum = neighborhood_sum + img[pos] * x[q] 
        result[p[0]+n, p[1]+n] = neighborhood_sum /(size * 2)
    return result

# %% [markdown]
# **<a id="#">Task 4.1.3.</a>** Test your above solution using the functions `prewitt_h` and `prewitt_v` for the previously loaded image and show the result:

# %%
plt.imread(prewitt_h(img_h, size = 3))

plt.imread(prewitt_v(img_v, size = 3))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 plt.imread(prewitt_h(img_h, size = 3))
#       3 plt.imread(prewitt_v(img_v, size = 3))
#
# File /usr/local/lib/python3.11/site-packages/matplotlib/pyplot.py:2389, in imread(fname, format)
#    2385 @_copy_docstring_and_deprecators(matplotlib.image.imread)
#    2386 def imread(
#    2387         fname: str | pathlib.Path | BinaryIO, format: str | None = None
#    2388 ) -> np.ndarray:
# -> 2389     return matplotlib.image.imread(fname, format)
#
# File /usr/local/lib/python3.11/site-packages/matplotlib/image.py:1525, in imread(fname, format)
#    1518 if isinstance(fname, str) and len(parse.urlparse(fname).scheme) > 1:
#    1519     # Pillow doesn't handle URLs directly.
#    1520     raise ValueError(
#    1521         "Please open the URL for reading and pass the "
#    1522         "result to Pillow, e.g. with "
#    1523         "``np.array(PIL.Image.open(urllib.request.urlopen(url)))``."
#    1524         )
# -> 1525 with img_open(fname) as image:
#    1526     return (_pil_png_to_float_array(image)
#    1527             if isinstance(image, PIL.PngImagePlugin.PngImageFile) else
#    1528             pil_to_array(image))
#
# File /usr/local/lib/python3.11/site-packages/PIL/ImageFile.py:117, in ImageFile.__init__(self, fp, filename)
#     115 try:
#     116     try:
# --> 117         self._open()
#     118     except (
#     119         IndexError,  # end of data
#     120         TypeError,  # end of data (ord)
#    (...)
#     123         struct.error,
#     124     ) as v:
#     125         raise SyntaxError(v) from v
#
# File /usr/local/lib/python3.11/site-packages/PIL/PngImagePlugin.py:703, in PngImageFile._open(self)
#     702 def _open(self):
# --> 703     if not _accept(self.fp.read(8)):
#     704         msg = "not a PNG file"
#     705         raise SyntaxError(msg)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'read'

# %% [markdown]
# **<a id="#">Task 4.1.4.</a>** Compare your results with the correct result image `data/lena_prewitt_h.tiff` and `data/lena_prewitt_v.tiff`:

# %%
correct_image_h = plt.imread('data/lena_prewitt_h.tiff')
numpy.allclose(img_h, correct_image_h, atol=1/255)

correct_image_v = plt.imread('data/lena_prewitt_v.tiff')
numpy.allclose(img_v, correct_image_v, atol=1/255)

# %% [markdown]
# ---
#
# ## Edge detection
#
# **<a id="#">Task 4.2.1.</a>** Use your results from **Task 4.1.2 – 4.1.3** to compute the *gradient magnitude* of the image:

# %% [markdown]
# **<a id="#">Task 4.2.2.</a>** Compare your result with the correct result image `data/lena_prewitt_gradmag.tiff`:

# %% [markdown]
# ---
#
# ## Sobel filters (bonus)
#
# **<a id="#">Task 4.3.1.</a>** Implement the two functions `sobel_h` and `sobel_v` for horizontal and vertical $3 \times 3$ Sobel filtering, respectively:

# %% [markdown]
# **<a id="#">Task 4.3.2.</a>** Test your above solution using the functions `sobel_h` and `sobel_v` for the previously loaded image and show the result:

# %% [markdown]
# **<a id="#">Task 4.3.3.</a>** Compare your results with the correct result image `data/lena_sobel_h.tiff` and `data/lena_sobel_v.tiff`:
